# %%
import numpy as np
from numpy.random import randn
import pandas as pd

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
dataset = randn(100)

# %%
sns.distplot(dataset, bins = 25)

# show kernel density estimation plot + histogram
# distplot allows combining the plots

# %%
sns.distplot(dataset, bins = 25, rug = True, hist = False)

# see the rug plot, don't see histogram

# %%
sns.distplot(dataset, bins = 25,
            kde_kws = {'color': 'indianred', 'label': 'KDE PLOT'},
            hist_kws = {'color': 'blue', 'label': 'HIST'})

# %%
from pandas import Series

ser1 = Series(dataset, name = 'My_data')

ser1
# Out:
# 0     0.714223
# 1    -0.623121
# 2    -0.440759
# 3     1.625911
# 4     0.018222
#         ...
# 95    0.754942
# 96   -1.495205
# 97   -0.012557
# 98   -0.512618
# 99   -1.340372
# Name: My_data, Length: 100, dtype: float64

# %%
# seaborn with pd.Series

sns.distplot(ser1, bins = 25)
